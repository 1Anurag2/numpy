# %%
# copy and view

# %%
import numpy as np
var = np.array([4,5,7,8,9])
print(var)
print()
c = var.copy()        # create copy of var in c variable 
print(c)
# Out:
# [4 5 7 8 9]
#
# [4 5 7 8 9]

# %%
x
