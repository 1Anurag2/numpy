# %%
# iterate

# %%
import numpy as np
var = np.array([3,4,5,6,7,8,9,1])
for i in var:
    print(i)
# Out:
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 1

# %%
# for iterate two dimenssion array

# %%
x = np.array([[]])
